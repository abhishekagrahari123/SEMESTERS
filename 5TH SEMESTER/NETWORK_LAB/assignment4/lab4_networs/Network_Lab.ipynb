# %%
import datetime
import pandas as pd
import numpy as np
import math
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from pandas import DataFrame
import seaborn as sns

# %%
d1 = pd.read_csv('PartA_Hybla_cwnd.csv')
d2 = pd.read_csv('PartA_Hybla_goodput.csv')
d3 = pd.read_csv('PartA_Hybla_throughput.csv')
d4 = pd.read_csv('PartA_Westwood_cwnd.csv')
d5 = pd.read_csv('PartA_Westwood_gp.csv')
d6 = pd.read_csv('PartA_Westwood_tp.csv')
d7 = pd.read_csv('PartA_Yeah_cwnd.csv')
d8 = pd.read_csv('PartA_Yeah_gp.csv')
d9 = pd.read_csv('PartA_Yeah_tp.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
x=d1.iloc[:,0]
y=d1.iloc[:,1]
plt.plot(x,y)
plt.show()

# %%
x=d2.iloc[:,0]
y=d2.iloc[:,1]
plt.plot(x,y)
plt.show()

# %%
x=d3.iloc[:,0]
y=d3.iloc[:,1]
plt.plot(x,y)
plt.show()

# %%
x=d4.iloc[:,0]
y=d4.iloc[:,1]
plt.plot(x,y)
plt.show()

# %%
x=d5.iloc[:,0]
y=d5.iloc[:,1]
plt.plot(x,y)
plt.show()

# %%
x=d6.iloc[:,0]
y=d6.iloc[:,1]
plt.plot(x,y)
plt.show()

# %%
x=d7.iloc[:,0]
y=d7.iloc[:,1]
plt.plot(x,y)
plt.show()

# %%
x=d8.iloc[:,0]
y=d8.iloc[:,1]
plt.plot(x,y)
plt.show()

# %%
x=d9.iloc[:,0]
y=d9.iloc[:,1]
plt.plot(x,y)
plt.show()
