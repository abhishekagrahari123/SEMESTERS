# %%
with open('n.txt') as f:
    lines = f.readlines()

output = []
for x in range(1,1000):
    output.append(int(lines[x][-7:-4]))
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import statistics

a = np.array(output)
a.sort()
mean = statistics.mean(a)
sd = statistics.stdev(a)
med = statistics.median(a)
print(med)
plt.plot(a, norm.pdf(a, mean, sd))
plt.xlabel('rtt(in ms)')
plt.ylabel('probability')
plt.show()

fig, axs = plt.subplots(1, 1,figsize =(10, 7), tight_layout = True)
axs.hist(a, bins = 20)
axs.set_xlabel('rtt(in ms)')
axs.set_ylabel('frequency')
plt.show()
# Out:
# 210

# %%
with open('ff00.txt') as f:
    lines = f.readlines()
output = []

for x in range(2,999):
    output.append(int(lines[x][-7:-4]))
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import statistics

a = np.array(output)
a.sort()
mean = statistics.mean(a)
sd = statistics.stdev(a)
med = statistics.median(a)
print(med)
plt.plot(a, norm.pdf(a, mean, sd))
plt.xlabel('rtt(in ms)')
plt.ylabel('probability')
plt.show()

fig, axs = plt.subplots(1, 1,figsize =(10, 7), tight_layout = True)
axs.hist(a, bins = 20)
axs.set_xlabel('rtt(in ms)')
axs.set_ylabel('frequency')
plt.show()
# Out:
# 205
